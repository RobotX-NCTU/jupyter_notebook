# %% [markdown]
# # SIFT feature

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('tutorial_data/park.jpg')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
sift = cv2.xfeatures2d.SIFT_create()
(kps, descriptors) = sift.detectAndCompute(gray,None)
img = cv2.drawKeypoints(gray,kps, img)

plt.subplot(111),plt.imshow(img,cmap = 'gray')
plt.title('MSER Regions'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
print len(kps)
# Out:
# 537

# %%
print kps[0].size
print kps[0].angle
print kps[0].pt
# Out:
# 1.97672617435
# 130.896057129
# (30.32628059387207, 12.611855506896973)

# %%
print len(descriptors)
# Out:
# 537

# %%
plt.plot(descriptors[0], '.'); plt.show()
